# %% [markdown]
# Replace repeats with *.

# %%
s='balloon'
r=s[0]
for i in range(1,len(s)): r+=('*' if s[i]==s[i-1] else s[i])
print(r)

# %% [markdown]
# Check anagram.

# %%
a='listen';b='silent'
print(sorted(a)==sorted(b))

# %% [markdown]
# Count words.

# %%
s='a b c d'
print(len(s.split()))

# %% [markdown]
# Count char.

# %%
s='banana'
print(s.count('a'))

# %% [markdown]
# Longest word length.

# %%
s='a bb ccc'
print(max(len(x) for x in s.split()))

# %% [markdown]
# Next vowel.

# %%
s='education';v='aeiou'
print(''.join(v[(v.index(c)+1)%5] if c in v else c for c in s))

# %% [markdown]
# Rotational palindrome.

# %%
s='aab'
print(any((s[i:]+s[:i])==(s[i:]+s[:i])[::-1] for i in range(len(s))))

# %% [markdown]
# Valid URL.

# %%
s='https://x.com'
print(s.startswith('http'))

# %% [markdown]
# Vowels and consonants.

# %%
s='abcde';v='aeiou'
print(sum(c in v for c in s), sum(c.isalpha() and c not in v for c in s))

# %% [markdown]
# Reverse tokens.

# %%
s='a b c'
print(' '.join(s.split()[::-1]))

# %% [markdown]
# Words b..d.

# %%
s='bad bed bid'
print([w for w in s.split() if w[0]=='b' and w[-1]=='d'])

# %% [markdown]
# 3-letter combos.

# %%
import itertools
print([''.join(p) for p in set(itertools.permutations('abcde',3))])

# %% [markdown]
# Remove extra spaces.

# %%
s='a   b'
print(' '.join(s.split()))

# %% [markdown]
# Reverse middle half.

# %%
s='abcd1234'
n=len(s);m=s[n//4:3*n//4][::-1]
print(s[:n//4]+m+s[3*n//4:])

# %% [markdown]
# Substring freq.

# %%
s='aabbb'
print('bbb')

# %% [markdown]
# Unique sorted.

# %%
s='mississippi'
print(''.join(sorted(set(s))))

# %% [markdown]
# Slice first-last o.

# %%
s='how now brown cow'
print(s[s.find('o'):s.rfind('o')])

# %% [markdown]
# Shift chars.

# %%
print(chr(ord('A')+2)+chr(ord('Z')-3))

# %% [markdown]
# Replace substring.

# %%
s='abracadabra'
print(s.replace('a','X',1))

# %% [markdown]
# Uppercase.

# %%
q='The quick brown fox'
print(q.upper())

# %% [markdown]
# Reverse.

# %%
q='The quick brown fox'
print(q[::-1])

# %% [markdown]
# Find word.

# %%
q='Knowledge is power.'
print(q.find('power'))

# %% [markdown]
# Regex search.

# %%
import re
s='Python Programming Language'
m=re.search('.*',s)
print(m.group())

# %% [markdown]
# Symmetric check.

# %%
s='abba'
print(s==s[::-1])

# %% [markdown]
# Delete i-th char.

# %%
s='hello'
i=1
print(s[:i]+s[i+1:])
